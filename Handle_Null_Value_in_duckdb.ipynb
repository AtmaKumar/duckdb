# %%
# !pip install duckdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.4 MB 29.5 MB/s
# ...

# %%
path="/content/sql_data_for_string_split_with_null.csv"

# %%
import duckdb
con=duckdb.connect()
q=f"""select * from '{path}' limit 100 """
data=con.execute(q).df()
data
# Out:
#    ProductId      Name    Tags
# 0        1.0      Ajay   Noida
# 1        2.0    Dinesh   Delhi
# 2        3.0    Suresh  Ballia
# 3        4.0   Animesh     NaN
# 4        5.0  Dipanshu   Delhi
# 5        6.0     vinod     NaN
# 6        NaN    Preeti  Jaipur
# 7        NaN   Chandan     NaN
# 8        9.0      Neha   Buxar

# %%
import duckdb
con=duckdb.connect()
q=f"""select * from '{path}' where Tags is not null limit 100 """
data=con.execute(q).df()
data
# Out:
#    ProductId      Name    Tags
# 0        1.0      Ajay   Noida
# 1        2.0    Dinesh   Delhi
# 2        3.0    Suresh  Ballia
# 3        5.0  Dipanshu   Delhi
# 4        NaN    Preeti  Jaipur
# 5        9.0      Neha   Buxar

# %%
import duckdb
con=duckdb.connect()
q=f"""select coalesce(Tags,10) from '{path}' limit 100 """
data=con.execute(q).df()
data
# Out:
#   COALESCE("Tags", 10)
# 0                Noida
# 1                Delhi
# 2               Ballia
# 3                   10
# 4                Delhi
# 5                   10
# 6               Jaipur
# 7                   10
# 8                Buxar
